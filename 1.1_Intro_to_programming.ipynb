# %% [markdown]
# <a href="https://colab.research.google.com/github/mechatronics-learning/MEC212-20264/blob/main/1.1_Intro_to_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1 Introduction to Programming in Python
#
# Welcome to your first Python practice notebook!
# This notebook will guide you through core programming fundamentals.
# ### 🎯 Instructions:
# 1. Read each concept description and problem statement.
# 2. Fill in the code where you see # TODO: Write your code here.
# 3. Run the cell by pressing Shift + Enter or clicking the ▶️ play button.
# 4. Verify your results against the expected output provided.

# %% [markdown]
# ### Exercise 1.1.1
# Use `print()` to show `Hello World`.
# Copy the code below and paste to `# TODO: Write your code here.`;
#
# `print('Hello World!')`

# %%
# TODO: Write your code here.

# %% [markdown]
# ### Exercise 1.1.2
# Change the word inside `print()` to show `I like programming`.

# %%
# TODO: Write your code here.

# %% [markdown]
# ### Exercise 1.1.3
#
# Python can be used as calculator.
# Calculate `3+4`

# %%
# TODO: Write your code here.

# %% [markdown]
# ## Exercise 1.1.4
#
# Use print() to display your name.

# %%
# TODO: Write your code here.

# %% [markdown]
# ### Exercise 1.1.5
#
# Use print() to display the following sentence:
#
# I am learning Python.

# %%
# TODO: Write your code here.

# %% [markdown]
# ### Exercise 1.1.6
#
# Python can perform basic mathematical calculations. Calculate:
#
# 10 - 3

# %%
# TODO: Write your code here.

# %% [markdown]
# ## Exercise 1.1.7
#
# Calculate:
#
# 5 * 4

# %%
# TODO: Write your code here.

# %% [markdown]
# ## Exercise 1.1.8
#
# Use print() to display two different sentences using two print() statements.
#
# Example of the required output:
#
# I am a Mechanical Engineering student.
# I am learning Python.

# %%
# TODO: Write your code here.
