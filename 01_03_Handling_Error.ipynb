# %% [markdown]
# # 1.3 - Handling Error

# %% [markdown]
# Error message is important information to identify mistakes in our program. Three basic error;
#
# 1. Runtime errors: Errors where syntactically valid code fails to execute, perhaps due to invalid user input.
# 2. Syntax errors: Errors where the code is not valid Python Syntax.
# 3. Semantic errors: Errors in logic: code executes without a problem, but the result is not what you expect. (Difficult to detect)

# %%
# Example 1: Runtime error
print(book)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Example 1: Runtime error
# ----> 2 print(book)
#
# NameError: name 'book' is not defined

# %%
# Example 2: Syntax error (Forgot closing parenthesis)
print("Hello World"
# Out:
#   Cell In[4], line 2
#     print("Hello World"
#                        ^
# SyntaxError: incomplete input

# %% [markdown]
# ### Exercise 1.3.1
#
# Copy paste the code below. Identify the error.
#
# ```python
# prints('Computer')
# ```

# %%
#TODO: Write your code here.

# %%
# ===== SOLUTION START =====
prints('Computer')
# ===== SOLUTION END =====
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # ===== SOLUTION START =====
# ----> 2 prints('Computer')
#       3 # ===== SOLUTION END =====
#
# NameError: name 'prints' is not defined
