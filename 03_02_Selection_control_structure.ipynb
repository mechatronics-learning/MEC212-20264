# %% [markdown]
# ---
# ## 3.1 Selection Control Structure
#
# A **selection control structure** tells the program to execute one block of code *or* another, depending on whether a condition is `True` or `False`. Without it, a program would behave identically every run, regardless of any sensor reading or input.
#
# Before writing Python code, engineers often sketch the logic as **pseudocode** — an informal step-by-step description using plain words — or as a **flowchart** using decision diamonds (◇). Both help you think through the branches before worrying about syntax.
#
# The example below shows how a pseudocode motor temperature check maps directly to Python `if`/`else`.

# %%
# Worked example — motor overheat check
# Pseudocode:
#   INPUT temperature
#   IF temperature > 90 THEN
#       PRINT "Activate cooling fan"
#   ELSE
#       PRINT "System normal"
#   END IF

temperature_c = 95.0   # degrees Celsius

if temperature_c > 90:             # decision node
    print("Activate cooling fan")  # True branch
else:
    print("System normal")         # False branch

# %% [markdown]
# ---
# ## 3.2 Boolean Data Type
#
# The **Boolean data type** (`bool`) holds exactly two values: `True` or `False`. Every condition inside an `if` statement must ultimately evaluate to one of these. In Python, `True` and `False` are equivalent to integers `1` and `0`, which is useful when storing a numeric fault flag in a data log.
#
# A **Boolean expression** is any combination of variables, values, and operators that produces `True` or `False` — for example, `temperature > 90` or `pressure == 200`.

# %%
# Worked example — Boolean values and expressions

temperature_c = 95.0
pressure_bar  = 210.0

# Boolean literals
sensor_ok = True
fault     = False
print(type(sensor_ok))    # <class 'bool'>
print(int(sensor_ok))     # 1
print(int(fault))         # 0

# Boolean expressions
print(temperature_c > 90)     # True
print(pressure_bar == 200)    # False
print(temperature_c <= 100)   # True

# %% [markdown]
# ### Exercise 3.2.1 — Overloaded Beam
#
# Assign a Boolean variable `is_overloaded` that is `True` when `beam_load_n = 3200` exceeds the maximum allowable load of 3000 N.
#
# Print the variable and its type.

# %%
# TODO: Write your code here

# %% [markdown]
# ### Exercise 3.2.2 — Sensor Range Check
#
# A temperature sensor is valid between 0 °C and 150 °C.
# Given `sensor_reading_c = 162`, assign `in_range` to `True` if the reading is within the valid range, otherwise `False`.
#
# Print `in_range`.

# %%
# TODO: Write your code here

# %% [markdown]
# ### Exercise 3.2.3 — PLC Fault Signal
#
# A PLC output uses 1 for fault and 0 for normal.
# Given `fault_detected = True`, compute `signal_output` as the integer equivalent of the Boolean and print it.

# %%
# TODO: Write your code here

# %% [markdown]
# ---
# ## 3.3 Relational Operators
#
# **Relational operators** compare two values and always return `True` or `False`. They are the basic building blocks of conditions.
#
# **Comparison Operators**
#
# | Operator | Meaning               | Example (`temp = 95`) | Result  |
# |----------|-----------------------|-----------------------|---------|
# | `==`     | Equal to              | `temp == 95`          | `True`  |
# | `!=`     | Not equal to          | `temp != 95`          | `False` |
# | `>`      | Greater than          | `temp > 90`           | `True`  |
# | `<`      | Less than             | `temp < 90`           | `False` |
# | `>=`     | Greater than or equal | `temp >= 95`          | `True`  |
# | `<=`     | Less than or equal    | `temp <= 100`         | `True`  |
#
# **Common mistake:** Do not use `=` inside a condition — that is assignment. Use `==` to compare.
#
# **Logical Operatiors**
#
# These operators combine two or more Boolean expression to produce a single Boolean results. There are used to build complex condition.
#
# `and` (Logical AND)
#
# `or` (Logical OR)
#
# `not` (Logical NOT)

# %%
# Example 1 — relational operators on engineering values

temperature_c = 95.0
pressure_bar  = 210.0
rpm           = 1500

print(temperature_c > 90)     # True  — over-temperature?
print(pressure_bar == 200)    # False — exact match
print(rpm >= 1000)            # True  — at or above minimum speed?
print(rpm != 0)               # True  — motor running?
print(temperature_c <= 100)   # True  — still below boiling?

# %%
# Example 2 - Logical operators on engineering values
# A process is considered to be in an over-temperature state if the temperature exceeds 90 degrees Celsius. 
# Check if the process is in an over-temperature state and if a color change is required.

temperature_c = 95.0
change_color = True

print(temperature_c > 90 and change_color)   # True  — over-temperature and change color?
print(temperature_c < 90 or change_color)    # True  — over-temperature or change color?
print(not change_color)                     # False — not changing color?
print(not (temperature_c > 90) and change_color)  # False — not over-temperature and change color?

# %% [markdown]
# ### Exercise 3.3.1 — Underloaded Bolt
#
# A bolt must carry at least 15 kN. Given `bolt_load_kn = 14.2`, write a relational expression that evaluates to `True` if the bolt is underloaded and print the result.

# %%
# TODO: Write your code here

# %% [markdown]
# ### Exercise 3.3.2 — Shaft Diameter Tolerance
#
# A machined shaft has a nominal diameter of 50.00 mm with tolerance ±0.05 mm.
# Given `measured_dia_mm = 50.03`, print two separate Boolean results:
# 1. Is the diameter within the upper limit (`<= 50.05`)?
# 2. Is it within the lower limit (`>= 49.95`)?

# %%
# TODO: Write your code here

# %% [markdown]
# ### Exercise 3.3.3 — All Six Relational Operators
#
# Given `applied_stress_mpa = 310` and `yield_stress_mpa = 250`, print the result of all six relational operators (`==`, `!=`, `>`, `<`, `>=`, `<=`) applied between them. Label each output.

# %%
# TODO: Write your code here

# %% [markdown]
# ### Exercise 3.3.4 — Conveyor Overspeed (Applied)
#
# A conveyor belt motor runs between 200 RPM and 1800 RPM. Given `motor_rpm = 1950`, use a relational expression to check if the motor is running **above** the maximum, then print an appropriate warning message.

# %%
# TODO: Write your code here
