# %% [markdown]
# ## 2.2 Identifiers, Variables, Constants & Reversed Words
#
# Identifiers are names for data in your program.Examples:
# | Term                        | Description                                                                                  | Example                                         |
# | --------------------------- | -------------------------------------------------------------------------------------------- | ----------------------------------------------- |
# | **Identifier**              | A name given to a variable, function, class, or other object.                                | `student_name`, `calculate_area`                |
# | **Variable**                | A named storage location whose value can change during program execution.                    | `age = 20`                                      |
# | **Constant**                | A value intended not to change. In Python, constants are written in uppercase by convention. | `PI = 3.14159`, `GRAVITY = 9.81`                |
# | **Reserved Word (Keyword)** | A word reserved by Python with a special meaning. It cannot be used as an identifier.        | `if`, `for`, `while`, `def`, `import`, `return` |

# %%
# Example 1: Clear engineering variable names
shaft_diameter_mm = 32

print(shaft_diameter_mm)
# Out:
# 32

# %%
# Example 2: Constants by convention (ALL_CAPS)
GRAVITY = 9.81
STEEL_DENSITY = 7850

print(f"g = {GRAVITY} m/s^2, rho_steel = {STEEL_DENSITY} kg/m^3")
# Out:
# g = 9.81 m/s^2, rho_steel = 7850 kg/m^3

# %%
# Example 3: Variables can change during process monitoring
tool_temperature_c = 45
print(f"Initial tool temperature: {tool_temperature_c} degC")

tool_temperature_c = 52
print(f"Updated tool temperature: {tool_temperature_c} degC")
# Out:
# Initial tool temperature: 45 degC
# Updated tool temperature: 52 degC

# %% [markdown]
# ### Exercise 2.2.1
# Determine whether each of the following names is a valid or invalid identifier in Python. If it is invalid, briefly explain why.
#
# ```
# user_name
# 2nd_attempt
# total$amount
# _hidden_value
# import
# ```

# %%
# TODO: You can practices here by define the variables and print().

# %%
# ===== SOLUTION START =====

# user_name – Valid
# 2nd_attempt - Invalid (Identifiers cannot start with a number.)
# total$amount - Invalid (Identifiers can only contain alphanumeric characters and underscores; special symbols like $ are not allowed.)
# _hidden_value - Valid (Starting with an underscore is allowed and often used for specific naming conventions.)
# import - Invalid (This is a reserved word/keyword in Python and cannot be used as an identifier name.)

# ===== SOLUTION END =====

# %% [markdown]
# ### Exercise 2.2.2
# Look at the list of words/names below. Categorize each one as a Variable (following standard naming conventions), a Constant (following standard Python naming conventions), or a Reserved Word (Keyword).
#
# ```
# MAX_SPEED
# False
# Age
# Def
# GRAVITY
# student_list
# ```

# %%
# TODO: You can practice here.

# %%
# ===== SOLUTION START =====
# MAX_SPEED - Constant (By convention, all-uppercase letters with underscores denote a constant in Python.)
# False - Reserved Word (A built-in boolean keyword.)
# age - Variable (Standard lowercase naming convention for variables.)
# def - Reserved Word (Keyword used to define a function.)
# GRAVITY – Constant
# student_list - Variable

# ===== SOLUTION END =====

# %% [markdown]
# ### Exercise 2.2.3
# Read the short Python code snippet below.
# ```python
# import math
# PI = 3.14159
# radius = 5
# def calculate_area(r):
#     return PI * (r ** 2)
# ```
# Identify one example from the code for each of the following terms:
# - Reserved Word:
# - Constant:
# - Variable (or parameter):
# - Identifier (Function name):

# %%
# TODO: You can pracetice here.

# %%
# ===== SOLUTION START =====
# Reserved Word: import, def, or return
# Constant: PI (It is written in uppercase to indicate it shouldn't be changed.)
# Variable (or parameter): radius or r
# Identifier (Function name): calculate_area (Note: PI, radius, math, and r are also technically identifiers!)

# ===== SOLUTION END =====

# %% [markdown]
# ## 2.3 Basic Data Types in Python
# Data types define the kind of value stored: integer, decimal, text, or true/false.
# Mechanical example: part count (int), diameter (float), sensor label (str), safety flag (bool).

# %%
# Example 1: int and float
bolt_count = 12
shaft_diameter_mm = 19.5

print(type(bolt_count), bolt_count)
print(type(shaft_diameter_mm), shaft_diameter_mm)
# Out:
# <class 'int'> 12
# <class 'float'> 19.5

# %%
#  Example 2: strings for labels and reports
sensor_id = "TC-07"
unit = "degC"
message = f"Sensor {sensor_id} reading unit: {unit}"
print(message)
# Out:
# Sensor TC-07 reading unit: degC

# %%
#  Example 3: bool from a safety comparison
stress_mpa = 180
yield_strength_mpa = 250
is_safe = stress_mpa < yield_strength_mpa

print(f"Safe condition? {is_safe}")
# Out:
# Safe condition? True

# %% [markdown]
# ### Exercise 2.3.1
# Look at the variables below. What is the Python data type of each variable? (Choose from: int, float, str, bool, list, dict)
# ```
# score = 95
# pi = 3.14159
# is_active = True
# username = "coder123"
# prices = [10.99, 5.50, 8.00]
# user_info = {"name": "Alice", "age": 28}
# ```

# %%
# TODO: You can practice here by using the type() function to check the data types of different variables.

# %%
# ===== SOLUTION START =====
score = 95
pi = 3.14159
is_active = True
username = "coder123"
prices = [10.99, 5.50, 8.00]
user_info = {"name": "Alice", "age": 28}

print(type(score))
print(type(pi))
print(type(username))
print(type(prices))
print(type(user_info))
# ===== SOLUTION END =====
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# ### Exercise 2.3.2
# The following code throws a TypeError. Why does this happen, and how would you fix it?
# ```python
# age = 25
# message = "I am " + age + " years old."
# print(message)
# ```

# %%
# TODO: You can do practice here.

# %%
# ===== SOLUTION START =====
# Because integer ‘age’ cannot be concatenated with string
# Fix, convert integer to string

age = 25
message = "I am " + str(age) + " years old."
print(message)
# ===== SOLUTION END =====
# Out:
# I am 25 years old.

# %% [markdown]
# ### Exercise 2.3.3
#
# Give example of data value for these data type:
#
# | Data Type | Data value |
# | -------- | -------- |
# | int (Integer)  | Example : 5, 0, -1, 3432342, -872  |
# | float (Floating-point number)  |-  |
# | bool (Boolean)  | -  |
# | str (String)  | -  |
# | list (List)  | -  |
# | dict (Dictionary)  | -  |

# %%
# TODO: You can do practice here.

# %%
# ===== SOLUTION START =====

integer_value = 5
float_value = 33.3452
boolean_value = False
string_value = "Hazimi Ismail"
list_value = [4.22, 3, 454, 232.433]
dictionary_value = {
    "Name": "Mazleenda",
    "Age": 38,
    "CGPA": 3.44
}

# ===== SOLUTION END =====
print(dictionary_value)
# Out:
# {'Name': 'Mazleenda', 'Age': 38, 'CGPA': 3.44}
