# %% [markdown]
# # 2.4 Arithmetic operators, precedence, and mathematical expression
#
# Python follows a specific order of operations, known as operator precedence, to evaluate expressions. This determines which operation is performed first when multiple operators are present in a single expression.
#
# | Operator     | Name           | Description                                            |
# |--------------|----------------|--------------------------------------------------------|
# | ``a + b``    | Addition       | Sum of ``a`` and ``b``                                 |
# | ``a - b``    | Subtraction    | Difference of ``a`` and ``b``                          |
# | ``a * b``    | Multiplication | Product of ``a`` and ``b``                             |
# | ``a / b``    | Division  | Quotient of ``a`` and ``b``                            |
# | ``a // b``   | Floor division | Quotient of ``a`` and ``b``, removing fractional parts |
# | ``a % b``    | Modulus        | Integer remainder after division of ``a`` by ``b``     |
# | ``a ** b``   | Exponentiation | ``a`` raised to the power of ``b``                        |

# %%
# Example 1: Addition, subtraction, multiplication, and division
(2+4)*(6-1)/2
# Out:
# 15.0

# %% [markdown]
# **Python as calculator**
#
# The colab notebook acts as a simple calculator, type an expression at it and it will produce the value. Expression syntax is straightforward: the operators +, -, * and / can be used to perform arithmetic; parentheses (()) can be used for grouping.

# %%
# Example 2: Simple calculation for each cell

50-5*6
# Out:
# 20

# %% [markdown]
# ### Exercise 2.4.1
# Identify which is operator or value:
#
# | No | Object | Operator/Value |
# | - | -------- | -------- |
# | 1 | * | - |
# | 2 | 'hello' | - |
# | 3 | -88.8 | - |
# | 4 | - | - |
# | 5 | / | - |
# | 6 | + | - |
# | 7 | 5 | - |

# %%
#TODO: You can do practice here.

# %%
# ===== SOLUTION START =====
# Operator
# Value
# Value
# Operator
# Operator
# Operator
# Value
# ===== SOLUTION END =====

# %% [markdown]
# ### Exercise 2.4.2
# Which operator is primarily used in Python to determine if a number is even or odd?

# %%
#TODO: You can do practice here.

# %%
# ===== SOLUTION START =====
# Modulus operator %
print(49 % 2)
print(50 % 2)
print('When the number is odd, the remainder is 1. When the number is even, the remainder is 0.')
# ===== SOLUTION END =====
# Out:
# 1
# 0

# %% [markdown]
# ### Exercise 2.4.3
#
# Write down the output from these arithmetic operations.
#
# | No | Arithmetic operation | Python Output |
# | - | -------- | -------- |
# | 1 | $4*2*1*0.3$ | - |
# | 2 | $4/3+3$ | - |
# | 3 | $8*2+(2**2)$ | - |
# | 4 | $32//2$ | - |
# | 5 | $49%3$ | - |
# | 6 | $10**2*(2+1)$ | - |
# | 7 | $50 + 10//3$ | - |

# %%
#TODO: Write your code here. You can add more cells.

# %%
# ===== SOLUTION START =====
print(4*2*1*0.3)
# ===== SOLUTION END =====
# Out:
# 2.4

# %%
print(8 * 2 + (2 ** 2))
# Out:
# 20

# %% [markdown]
# # 2.5 Assignment Statement
#
# In Python, an assignment statement is a fundamental operation used to bind a value to a variable name. It's how you store data in your program's memory so you can refer to and manipulate it later.
# The most common form of an assignment statement uses the assignment operator (=)
#
# ```python
# variable_name = value
# ```

# %%
# Example 1: Set the variable value to 10
score = 10
print(score)
# Out:
# 10

# %%
# Example 2: Update the variable value to 15
score = 15
print(score)
# Out:
# 15

# %%
# Example 3: Assign the result back to the same variable
score = score + 5
print(score)
# Out:
# 20
